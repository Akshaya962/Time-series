# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

from scipy import stats
import statsmodels.api as sm

# %%
dataset = pd.read_csv("Super Store.csv", encoding = 'unicode_escape')
dataset.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 3       6  CA-2014-115812    6/9/2014   6/14/2014  Standard Class    BH-11710
# 4      11  CA-2014-115812    6/9/2014   6/14/2014  Standard Class    BH-11710
#
#      Customer Name   Segment        Country             City  ... Postal Code  \
# 0      Claire Gute  Consumer  United States        Henderson  ...       42420
# 1      Claire Gute  Consumer  United States        Henderson  ...       42420
# 2   Sean O'Donnell  Consumer  United States  Fort Lauderdale  ...       33311
# 3  Brosina Hoffman  Consumer  United States      Los Angeles  ...       90032
# 4  Brosina Hoffman  Consumer  United States      Los Angeles  ...       90032
#
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2121 entries, 0 to 2120
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         2121 non-null   int64
#  1   Order ID       2121 non-null   object
#  2   Order Date     2121 non-null   datetime64[ns]
#  3   Ship Date      2121 non-null   object
#  4   Ship Mode      2121 non-null   object
#  5   Customer ID    2121 non-null   object
#  6   Customer Name  2121 non-null   object
#  7   Segment        2121 non-null   object
#  8   Country        2121 non-null   object
#  9   City           2121 non-null   object
#  10  State          2121 non-null   object
#  11  Postal Code    2121 non-null   int64
#  12  Region         2121 non-null   object
#  13  Product ID     2121 non-null   object
#  14  Category       2121 non-null   object
#  15  Sub-Category   2121 non-null   object
#  16  Product Name   2121 non-null   object
# ...

# %%
dataset['Order Date'] = pd.to_datetime(dataset['Order Date'])

# %%
set(dataset['Category'])
# Out:
# {'Furniture'}

# %%
set(dataset['Sub-Category'])
# Out:
# {'Bookcases', 'Chairs', 'Furnishings', 'Tables'}

# %%
Chairs = dataset.loc[dataset['Sub-Category']=='Chairs']

# %%
Chairs.head()
# Out:
#     Row ID        Order ID Order Date   Ship Date       Ship Mode Customer ID  \
# 1        2  CA-2016-152156 2016-11-08  11/11/2016    Second Class    CG-12520
# 5       24  US-2017-156909 2017-07-16   7/18/2017    Second Class    SF-20065
# 11      40  CA-2015-117415 2015-12-27  12/31/2015  Standard Class    SN-20710
# 13      53  CA-2015-115742 2015-04-18   4/22/2015  Standard Class    DP-13000
# 14      58  CA-2016-111682 2016-06-17   6/18/2016     First Class    TB-21055
#
#       Customer Name      Segment        Country          City  ...  \
# 1       Claire Gute     Consumer  United States     Henderson  ...
# 5   Sandra Flanagan     Consumer  United States  Philadelphia  ...
# 11     Steve Nguyen  Home Office  United States       Houston  ...
# 13    Darren Powers     Consumer  United States    New Albany  ...
# 14  Ted Butterfield     Consumer  United States          Troy  ...
#
#    Postal Code   Region       Product ID   Category Sub-Category  \
# ...

# %%
set(Chairs['Sub-Category'])
# Out:
# {'Chairs'}

# %%
Furniture = dataset.loc[dataset['Category']=='Furniture']

# %%
Furniture.head()
# Out:
#    Row ID        Order ID Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08  11/11/2016    Second Class    CG-12520
# 2       4  US-2015-108966 2015-10-11  10/18/2015  Standard Class    SO-20335
# 3       6  CA-2014-115812 2014-06-09   6/14/2014  Standard Class    BH-11710
# 4      11  CA-2014-115812 2014-06-09   6/14/2014  Standard Class    BH-11710
#
#      Customer Name   Segment        Country             City  ... Postal Code  \
# 0      Claire Gute  Consumer  United States        Henderson  ...       42420
# 1      Claire Gute  Consumer  United States        Henderson  ...       42420
# 2   Sean O'Donnell  Consumer  United States  Fort Lauderdale  ...       33311
# 3  Brosina Hoffman  Consumer  United States      Los Angeles  ...       90032
# 4  Brosina Hoffman  Consumer  United States      Los Angeles  ...       90032
#
# ...

# %%
len(Furniture)
# Out:
# 2121

# %%
print(Furniture['Order Date'].min())
print(Furniture['Order Date'].max())
# Out:
# 2014-01-06 00:00:00
# 2017-12-30 00:00:00

# %%
Furniture.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
cols = ['Row ID', 'Order ID', 'Ship Date', 'Ship Mode',
       'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
       'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
       'Product Name', 'Sales', 'Quantity', 'Discount']

# %%
Furniture.drop(cols, axis=1, inplace=True)

# %%
Furniture.head()
# Out:
#   Order Date    Profit
# 0 2016-11-08   41.9136
# 1 2016-11-08  219.5820
# 2 2015-10-11 -383.0310
# 3 2014-06-09   14.1694
# 4 2014-06-09   85.3092

# %%
Furniture.sort_values('Order Date')
# Out:
#      Order Date    Profit
# 1577 2014-01-06  746.4078
# 1626 2014-01-07  -53.7096
# 181  2014-01-10   21.2954
# 150  2014-01-11    3.0814
# 631  2014-01-13   87.3504
# ...         ...       ...
# 1619 2017-12-29   77.6250
# 1617 2017-12-29  314.0384
# 1057 2017-12-29   37.4144
# 1618 2017-12-29   87.2842
# 186  2017-12-30   12.1176
#
# [2121 rows x 2 columns]

# %%
Furniture = Furniture.groupby('Order Date')['Profit'].sum().reset_index()

# %%
Furniture.head()
# Out:
#   Order Date    Profit
# 0 2014-01-06  746.4078
# 1 2014-01-07  -53.7096
# 2 2014-01-10   21.2954
# 3 2014-01-11    3.0814
# 4 2014-01-13   91.2798

# %%
Furniture.tail()
# Out:
#     Order Date    Profit
# 884 2017-12-24  222.9092
# 885 2017-12-25   -7.0763
# 886 2017-12-28  -49.6680
# 887 2017-12-29  492.6236
# 888 2017-12-30   12.1176
